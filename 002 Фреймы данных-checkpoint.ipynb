# %%
import pandas as pd
data = pd.read_csv("http://video.ittensive.com/python-advanced/internet-2017.csv", na_values="NA", decimal=",")
data.fillna(0, axis=1, inplace=True)
print (data.head())
data_array = data.values
print (data_array)
# Out:
#                  Регион  \
# 0  Российская Федерация
# 1     БЕЛГОРОДСКАЯ ОБЛ.
# 2         БРЯНСКАЯ ОБЛ.
# 3     ВЛАДИМИРСКАЯ ОБЛ.
# 4     ВОРОНЕЖСКАЯ  ОБЛ.
#
#    Число абонентов фиксированного широкополосного доступа к сети Интернет на 100 человек населения
# 0                                              14.44
# 1                                               9.83
# 2                                              12.46
# 3                                              12.38
# 4                                              16.19
# [['Российская Федерация' 14.44]
#  ['БЕЛГОРОДСКАЯ ОБЛ.' 9.83]
#  ['БРЯНСКАЯ ОБЛ.' 12.46]
#  ['ВЛАДИМИРСКАЯ ОБЛ.' 12.38]
#  ['ВОРОНЕЖСКАЯ  ОБЛ.' 16.19]
#  ['ИВАНОВСКАЯ ОБЛ.' 10.5]
#  ['КАЛУЖСКАЯ ОБЛ.' 15.92]
#  ['КОСТРОМСКАЯ ОБЛ.' 16.38]
#  ['КУРСКАЯ ОБЛ.' 10.48]
#  ['ЛИПЕЦКАЯ ОБЛ.' 12.09]
#  ['МОСКОВСКАЯ ОБЛ.' 7.92]
#  ['ОРЛОВСКАЯ ОБЛ.' 11.76]
#  ['РЯЗАНСКАЯ ОБЛ.' 10.58]
#  ['СМОЛЕНСКАЯ ОБЛ.' 13.48]
#  ['ТАМБОВСКАЯ ОБЛ.' 12.36]
#  ['ТВЕРСКАЯ ОБЛ.' 10.45]
# ...
